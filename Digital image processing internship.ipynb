# %%
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks

# Load and preprocess CIFAR-10 data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# Define the CNN model
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))

# Compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# Define early stopping callback
# early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Train the model with early stopping
model.fit(x_train, y_train, epochs=20,validation_data=(x_test, y_test))

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 70s 1ms/sample - loss: 1.5122 - acc: 0.4506 - val_loss: 1.2295 - val_acc: 0.5586
# Epoch 2/20
# 50000/50000 [==============================] - 65s 1ms/sample - loss: 1.1475 - acc: 0.5943 - val_loss: 1.0978 - val_acc: 0.6059
# Epoch 3/20
# 50000/50000 [==============================] - 80s 2ms/sample - loss: 0.9812 - acc: 0.6554 - val_loss: 0.9683 - val_acc: 0.6620
# Epoch 4/20
# 50000/50000 [==============================] - 65s 1ms/sample - loss: 0.8861 - acc: 0.6901 - val_loss: 1.0119 - val_acc: 0.6510
# Epoch 5/20
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.8120 - acc: 0.7131 - val_loss: 0.8988 - val_acc: 0.6876
# Epoch 6/20
# 50000/50000 [==============================] - 65s 1ms/sample - loss: 0.7523 - acc: 0.7354 - val_loss: 0.9232 - val_acc: 0.6843
# Epoch 7/20
# 50000/50000 [==============================] - 65s 1ms/sample - loss: 0.7023 - acc: 0.7546 - val_loss: 0.8791 - val_acc: 0.7010
# Epoch 8/20
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.6594 - acc: 0.7684 - val_loss: 0.9279 - val_acc: 0.6923
# Epoch 9/20
# 50000/50000 [==============================] - 66s 1ms/sample - loss: 0.6159 - acc: 0.7812 - val_loss: 0.8758 - val_acc: 0.7071
# Epoch 10/20
# 50000/50000 [==============================] - 65s 1ms/sample - loss: 0.5770 - acc: 0.7963 - val_loss: 0.9039 - val_acc: 0.7093
# Epoch 11/20
# 50000/50000 [==============================] - 65s 1ms/sample - loss: 0.5395 - acc: 0.8066 - val_loss: 0.9394 - val_acc: 0.7026
# Epoch 12/20
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5034 - acc: 0.8205 - val_loss: 0.9743 - val_acc: 0.6953
# Epoch 13/20
# 50000/50000 [==============================] - 65s 1ms/sample - loss: 0.4699 - acc: 0.8329 - val_loss: 0.9699 - val_acc: 0.7030
# Epoch 14/20
# 50000/50000 [==============================] - 65s 1ms/sample - loss: 0.4439 - acc: 0.8400 - val_loss: 1.0111 - val_acc: 0.6980
# Epoch 15/20
# 50000/50000 [==============================] - 65s 1ms/sample - loss: 0.4093 - acc: 0.8547 - val_loss: 1.0709 - val_acc: 0.7016
# Epoch 16/20
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.3856 - acc: 0.8616 - val_loss: 1.0879 - val_acc: 0.7007
# Epoch 17/20
# 50000/50000 [==============================] - 65s 1ms/sample - loss: 0.3677 - acc: 0.8688 - val_loss: 1.1147 - val_acc: 0.7079
# Epoch 18/20
# 50000/50000 [==============================] - 65s 1ms/sample - loss: 0.3382 - acc: 0.8790 - val_loss: 1.1684 - val_acc: 0.6986
# Epoch 19/20
# 50000/50000 [==============================] - 65s 1ms/sample - loss: 0.3138 - acc: 0.8863 - val_loss: 1.1785 - val_acc: 0.6956
# Epoch 20/20
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.2964 - acc: 0.8917 - val_loss: 1.2726 - val_acc: 0.6931
#
# Test accuracy: 0.6931

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import ResNet50

# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Preprocess the data
x_train = x_train / 255.0
x_test = x_test / 255.0
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Use pre-trained ResNet50 as a base model
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(32, 32, 3))

# Build a custom model on top of ResNet50
model = models.Sequential()
model.add(base_model)
model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Print the model summary
model.summary()

# Train the model
model.fit(x_train, y_train, epochs=20, validation_data=(x_test, y_test))

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 1, 1, 2048)        23587712
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               262272
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 23851274 (90.99 MB)
# Trainable params: 23798154 (90.78 MB)
# Non-trainable params: 53120 (207.50 KB)
# _________________________________________________________________
# Epoch 1/20
# 1563/1563 [==============================] - 128s 55ms/step - loss: 1.5320 - accuracy: 0.4670 - val_loss: 1.7328 - val_accuracy: 0.3860
# Epoch 2/20
# 1563/1563 [==============================] - 82s 53ms/step - loss: 1.2466 - accuracy: 0.5705 - val_loss: 1.5803 - val_accuracy: 0.4877
# Epoch 3/20
# 1563/1563 [==============================] - 81s 52ms/step - loss: 1.1236 - accuracy: 0.6134 - val_loss: 1.2488 - val_accuracy: 0.5610
# Epoch 4/20
# 1563/1563 [==============================] - 82s 52ms/step - loss: 1.1198 - accuracy: 0.6124 - val_loss: 1.6905 - val_accuracy: 0.4437
# Epoch 5/20
# 1563/1563 [==============================] - 82s 53ms/step - loss: 1.0561 - accuracy: 0.6331 - val_loss: 1.3398 - val_accuracy: 0.5543
# Epoch 6/20
# 1563/1563 [==============================] - 82s 52ms/step - loss: 1.0587 - accuracy: 0.6328 - val_loss: 1.2407 - val_accuracy: 0.5761
# Epoch 7/20
# 1563/1563 [==============================] - 83s 53ms/step - loss: 1.0430 - accuracy: 0.6356 - val_loss: 1.0954 - val_accuracy: 0.6209
# Epoch 8/20
# 1563/1563 [==============================] - 83s 53ms/step - loss: 0.9924 - accuracy: 0.6479 - val_loss: 1.0435 - val_accuracy: 0.6314
# Epoch 9/20
# 1563/1563 [==============================] - 83s 53ms/step - loss: 1.0181 - accuracy: 0.6435 - val_loss: 1.2666 - val_accuracy: 0.5811
# Epoch 10/20
# 1563/1563 [==============================] - 83s 53ms/step - loss: 0.9279 - accuracy: 0.6791 - val_loss: 0.9115 - val_accuracy: 0.6984
# Epoch 11/20
# 1563/1563 [==============================] - 83s 53ms/step - loss: 0.9073 - accuracy: 0.6845 - val_loss: 0.9682 - val_accuracy: 0.6667
# Epoch 12/20
# 1563/1563 [==============================] - 82s 52ms/step - loss: 0.9533 - accuracy: 0.6661 - val_loss: 2.2909 - val_accuracy: 0.3296
# Epoch 13/20
# 1563/1563 [==============================] - 83s 53ms/step - loss: 1.0556 - accuracy: 0.6313 - val_loss: 1.0376 - val_accuracy: 0.6403
# Epoch 14/20
# 1563/1563 [==============================] - 84s 53ms/step - loss: 0.9091 - accuracy: 0.6844 - val_loss: 0.9004 - val_accuracy: 0.7147
# Epoch 15/20
# 1563/1563 [==============================] - 84s 53ms/step - loss: 0.9441 - accuracy: 0.6764 - val_loss: 1.0005 - val_accuracy: 0.6625
# Epoch 16/20
# 1563/1563 [==============================] - 82s 52ms/step - loss: 0.9772 - accuracy: 0.6644 - val_loss: 0.9442 - val_accuracy: 0.6777
# Epoch 17/20
# 1563/1563 [==============================] - 79s 51ms/step - loss: 0.7582 - accuracy: 0.7404 - val_loss: 1.0532 - val_accuracy: 0.6508
# Epoch 18/20
# 1563/1563 [==============================] - 80s 51ms/step - loss: 0.7433 - accuracy: 0.7443 - val_loss: 0.7274 - val_accuracy: 0.7503
# Epoch 19/20
# 1563/1563 [==============================] - 81s 52ms/step - loss: 0.6438 - accuracy: 0.7799 - val_loss: 0.8357 - val_accuracy: 0.7304
# Epoch 20/20
# 1563/1563 [==============================] - 81s 52ms/step - loss: 0.6428 - accuracy: 0.7811 - val_loss: 1.7520 - val_accuracy: 0.4743
# 313/313 - 3s - loss: 1.7520 - accuracy: 0.4743 - 3s/epoch - 10ms/step
#
# Test accuracy: 0.47429999709129333

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Preprocess the data
x_train = x_train / 255.0
x_test = x_test / 255.0
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Use pre-trained MobileNetV2 as a base model
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(32, 32, 3))

# Build a custom model on top of MobileNetV2
model = models.Sequential()
model.add(base_model)
model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# Compile the model with a lower learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# Print the model summary
model.summary()

# Data Augmentation
datagen = ImageDataGenerator(rotation_range=20, width_shift_range=0.2, height_shift_range=0.2, horizontal_flip=True)
datagen.fit(x_train)

# Train the model with data augmentation and early stopping
history = model.fit(datagen.flow(x_train, y_train, batch_size=32), epochs=20, validation_data=(x_test, y_test), verbose=1)

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print(f'Test accuracy: {test_acc}')
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Func  (None, 1, 1, 1280)        2257984
#  tional)
#
#  global_average_pooling2d_5  (None, 1280)              0
#   (GlobalAveragePooling2D)
#
#  dense_10 (Dense)            (None, 128)               163968
#
#  dense_11 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 2423242 (9.24 MB)
# Trainable params: 2389130 (9.11 MB)
# Non-trainable params: 34112 (133.25 KB)
# _________________________________________________________________
# Epoch 1/20
# 1563/1563 [==============================] - 94s 46ms/step - loss: 1.5811 - accuracy: 0.4462 - val_loss: 1.6192 - val_accuracy: 0.4385
# Epoch 2/20
# 1563/1563 [==============================] - 68s 44ms/step - loss: 1.2463 - accuracy: 0.5681 - val_loss: 1.9110 - val_accuracy: 0.5070
# Epoch 3/20
# 1563/1563 [==============================] - 72s 46ms/step - loss: 1.2036 - accuracy: 0.5859 - val_loss: 1.8161 - val_accuracy: 0.4902
# Epoch 4/20
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.2393 - accuracy: 0.5715 - val_loss: 2.5812 - val_accuracy: 0.4042
# Epoch 5/20
# 1563/1563 [==============================] - 70s 44ms/step - loss: 1.1997 - accuracy: 0.5811 - val_loss: 1.6919 - val_accuracy: 0.5530
# Epoch 6/20
# 1563/1563 [==============================] - 72s 46ms/step - loss: 1.1147 - accuracy: 0.6140 - val_loss: 1.7369 - val_accuracy: 0.5426
# Epoch 7/20
# 1563/1563 [==============================] - 71s 45ms/step - loss: 1.1834 - accuracy: 0.5865 - val_loss: 1.6089 - val_accuracy: 0.4974
# Epoch 8/20
# 1563/1563 [==============================] - 68s 44ms/step - loss: 1.1090 - accuracy: 0.6141 - val_loss: 1.5388 - val_accuracy: 0.5467
# Epoch 9/20
# 1563/1563 [==============================] - 65s 42ms/step - loss: 1.1259 - accuracy: 0.6122 - val_loss: 2.9608 - val_accuracy: 0.3812
# Epoch 10/20
# 1563/1563 [==============================] - 65s 42ms/step - loss: 1.3005 - accuracy: 0.5432 - val_loss: 1.5801 - val_accuracy: 0.5082
# Epoch 11/20
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.2319 - accuracy: 0.5681 - val_loss: 1.5318 - val_accuracy: 0.5025
# Epoch 12/20
# 1563/1563 [==============================] - 68s 44ms/step - loss: 1.1655 - accuracy: 0.5919 - val_loss: 1.7820 - val_accuracy: 0.4532
# Epoch 13/20
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.1782 - accuracy: 0.5889 - val_loss: 2.4668 - val_accuracy: 0.2521
# Epoch 14/20
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.3222 - accuracy: 0.5317 - val_loss: 1.3584 - val_accuracy: 0.5101
# Epoch 15/20
# 1563/1563 [==============================] - 67s 43ms/step - loss: 1.1529 - accuracy: 0.5876 - val_loss: 1.9168 - val_accuracy: 0.4165
# Epoch 16/20
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.1436 - accuracy: 0.5954 - val_loss: 1.4652 - val_accuracy: 0.5201
# Epoch 17/20
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.0848 - accuracy: 0.6172 - val_loss: 1.9369 - val_accuracy: 0.3192
# Epoch 18/20
# 1563/1563 [==============================] - 66s 43ms/step - loss: 1.1734 - accuracy: 0.5850 - val_loss: 1.3786 - val_accuracy: 0.5459
# Epoch 19/20
# 1563/1563 [==============================] - 66s 42ms/step - loss: 1.1697 - accuracy: 0.5875 - val_loss: 1.1528 - val_accuracy: 0.6036
# Epoch 20/20
# 1563/1563 [==============================] - 66s 42ms/step - loss: 1.0643 - accuracy: 0.6290 - val_loss: 1.1349 - val_accuracy: 0.5947
# 313/313 - 2s - loss: 1.1349 - accuracy: 0.5947 - 2s/epoch - 6ms/step
# Test accuracy: 0.5946999788284302
